# %%
# importing empath 
from empath import Empath
from empath import helpers as util

# %%
# importing libraries and empath class 
from collections import defaultdict
import os
import sys
from collections import defaultdict
import requests
import json
class Empath:
    def __init__(self, backend_url="http://54.148.189.209:8000"):
        self.cats = defaultdict(list)
        self.staging = {}
        self.backend_url = backend_url
        self.base_dir = os.path.dirname(util.__file__)
        #print(self.base_dir)
        self.inv_cache = {}
        #loads the default empath categories 
        self.load(self.base_dir+"/data/categories.tsv")
        # loads the user-written categories 
        for f in os.listdir(self.base_dir+"/data/user/"):
            if len(f.split(".")) > 1 and f.split(".")[1] == "empath":
                self.load(self.base_dir+"/data/user/"+f)
    def load(self,file):
        with open(file,"r") as f:
            for line in f:
                cols = line.strip().split("\t")
                name = cols[0]
                terms = cols[1:]
                for t in set(terms):
                    self.cats[name].append(t)
                    #self.invcats[t].append(name)
    def analyze_term_window(self,doc,targets,categories=None,window_size=10,normalize=False):
        tokenizer = util.window_tokenizer(window_size,targets)
        return self.analyze(doc,categories,tokenizer,normalize)
    def analyze(self,doc,categories=None,tokenizer="default",normalize=False):
        if isinstance(doc,list):
            doc = "\n".join(doc)
        if tokenizer == "default":
            tokenizer = util.default_tokenizer
        elif tokenizer == "bigrams":
            tokenizer = util.bigram_tokenizer
        if not hasattr(tokenizer,"__call__"):
            raise Exception("invalid tokenizer")
        if not categories:
            categories = self.cats.keys()
        invcats = defaultdict(list)
        key = tuple(sorted(categories))
        if key in self.inv_cache:
            invcats = self.inv_cache[key]
        else:
            for k in categories:
                for t in self.cats[k]: invcats[t].append(k)
            self.inv_cache[key] = invcats
        count = {}
        tokens = 0.0
        for cat in categories: count[cat] = 0.0
        for tk in tokenizer(doc):
            tokens += 1.0
            for cat in invcats[tk]:
                count[cat]+=1.0
        if normalize:
            for cat in count.keys():
                if tokens == 0:
                    return None
                else:
                    count[cat] = count[cat] / tokens
        return count
    def create_category(self,name,seeds,model="fiction",size=100,write=True):
        resp = requests.post(self.backend_url + "/create_category", json={"terms":seeds,"size":size,"model":model})
        #return(resp.text)
        #print(resp.text)
        results = json.loads(resp.text)
        self.cats[name] = list(set(results))
        if write:
            with open(self.base_dir+"/data/user/"+name+".empath","w") as f:
                f.write("\t".join([name]+results))
    def delete_category(self,name):
        if name in self.cats: del self.cats[name]
        filename = self.base_dir+"/data/user/"+name+".empath"
        if os.path.isfile(filename):
            os.remove(filename)

# %%
#print(len(wordlist))

# %%
# wordlist is created with the empath categories 
lexicon = Empath()
#print(lexicon.base_dir)
emp = lexicon.analyze("Testing", normalize=True)
#print(emp)
#print(emp.items)
wordlist = []
# Loop that deletes the extra 2's that overwrote the original file 
for word, value in emp.items():
    if word[-1] != '2': 
        wordlist.append(word)
    else: 
        #print("okay")
        lexicon.delete_category(word)
print(wordlist)
# Out:
# ['help', 'office', 'dance', 'money', 'wedding', 'domestic_work', 'sleep', 'medical_emergency', 'cold', 'hate', 'cheerfulness', 'aggression', 'occupation', 'envy', 'anticipation', 'family', 'vacation', 'crime', 'attractive', 'masculine', 'prison', 'health', 'pride', 'dispute', 'nervousness', 'government', 'weakness', 'horror', 'swearing_terms', 'leisure', 'suffering', 'royalty', 'wealthy', 'tourism', 'furniture', 'school', 'magic', 'beach', 'journalism', 'morning', 'banking', 'social_media', 'exercise', 'night', 'kill', 'blue_collar_job', 'art', 'ridicule', 'play', 'computer', 'college', 'optimism', 'stealing', 'real_estate', 'home', 'divine', 'sexual', 'fear', 'irritability', 'superhero', 'business', 'driving', 'pet', 'childish', 'cooking', 'exasperation', 'religion', 'hipster', 'internet', 'surprise', 'reading', 'worship', 'leader', 'independence', 'movement', 'body', 'noise', 'eating', 'medieval', 'zest', 'confusion', 'water', 'sports', 'death', 'healing', 'legend', 'heroic', 'celebration', 'restaurant', 'violence', 'programming', 'dominant_heirarchical', 'military', 'neglect', 'swimming', 'exotic', 'love', 'hiking', 'communication', 'hearing', 'order', 'sympathy', 'hygiene', 'weather', 'anonymity', 'trust', 'ancient', 'deception', 'fabric', 'air_travel', 'fight', 'dominant_personality', 'music', 'vehicle', 'politeness', 'toy', 'farming', 'meeting', 'war', 'speaking', 'listen', 'urban', 'shopping', 'disgust', 'fire', 'tool', 'phone', 'gain', 'sound', 'injury', 'sailing', 'rage', 'science', 'work', 'appearance', 'valuable', 'warmth', 'youth', 'sadness', 'fun', 'emotional', 'joy', 'affection', 'traveling', 'fashion', 'ugliness', 'lust', 'shame', 'torment', 'economics', 'anger', 'politics', 'ship', 'clothing', 'car', 'strength', 'technology', 'breaking', 'shape_and_size', 'power', 'white_collar_job', 'animal', 'party', 'terrorism', 'smell', 'disappointment', 'poor', 'plant', 'pain', 'beauty', 'timidity', 'philosophy', 'negotiate', 'negative_emotion', 'cleaning', 'messaging', 'competing', 'law', 'friends', 'payment', 'achievement', 'alcohol', 'liquid', 'feminine', 'weapon', 'children', 'monster', 'ocean', 'giving', 'contentment', 'writing', 'rural', 'positive_emotion', 'musical']

# %%
lexicon.cats.keys()
# Out:
# dict_keys(['help', 'office', 'dance', 'money', 'wedding', 'domestic_work', 'sleep', 'medical_emergency', 'cold', 'hate', 'cheerfulness', 'aggression', 'occupation', 'envy', 'anticipation', 'family', 'vacation', 'crime', 'attractive', 'masculine', 'prison', 'health', 'pride', 'dispute', 'nervousness', 'government', 'weakness', 'horror', 'swearing_terms', 'leisure', 'suffering', 'royalty', 'wealthy', 'tourism', 'furniture', 'school', 'magic', 'beach', 'journalism', 'morning', 'banking', 'social_media', 'exercise', 'night', 'kill', 'blue_collar_job', 'art', 'ridicule', 'play', 'computer', 'college', 'optimism', 'stealing', 'real_estate', 'home', 'divine', 'sexual', 'fear', 'irritability', 'superhero', 'business', 'driving', 'pet', 'childish', 'cooking', 'exasperation', 'religion', 'hipster', 'internet', 'surprise', 'reading', 'worship', 'leader', 'independence', 'movement', 'body', 'noise', 'eating', 'medieval', 'zest', 'confusion', 'water', 'sports', 'death', 'healing', 'legend', 'heroic', 'celebration', 'restaurant', 'violence', 'programming', 'dominant_heirarchical', 'military', 'neglect', 'swimming', 'exotic', 'love', 'hiking', 'communication', 'hearing', 'order', 'sympathy', 'hygiene', 'weather', 'anonymity', 'trust', 'ancient', 'deception', 'fabric', 'air_travel', 'fight', 'dominant_personality', 'music', 'vehicle', 'politeness', 'toy', 'farming', 'meeting', 'war', 'speaking', 'listen', 'urban', 'shopping', 'disgust', 'fire', 'tool', 'phone', 'gain', 'sound', 'injury', 'sailing', 'rage', 'science', 'work', 'appearance', 'valuable', 'warmth', 'youth', 'sadness', 'fun', 'emotional', 'joy', 'affection', 'traveling', 'fashion', 'ugliness', 'lust', 'shame', 'torment', 'economics', 'anger', 'politics', 'ship', 'clothing', 'car', 'strength', 'technology', 'breaking', 'shape_and_size', 'power', 'white_collar_job', 'animal', 'party', 'terrorism', 'smell', 'disappointment', 'poor', 'plant', 'pain', 'beauty', 'timidity', 'philosophy', 'negotiate', 'negative_emotion', 'cleaning', 'messaging', 'competing', 'law', 'friends', 'payment', 'achievement', 'alcohol', 'liquid', 'feminine', 'weapon', 'children', 'monster', 'ocean', 'giving', 'contentment', 'writing', 'rural', 'positive_emotion', 'musical'])

# %%
# creates "wordsToUse" which are seed words for each category 

# Open the category file 
catFile = open("categories1.tsv", "r")
#catFile = open("/Users/mahumshah/Downloads/categories1.tsv", "r")
# Outer for loop
# variable to store the seed words that I created 
wordsToUse = []
j = 0 
#print(wordlist)
#categoryList = wordlist 
#print(categoryList)
# loops through each line in the file 
for line in catFile: 
    categoryList = line.strip("\n").split("\t")
    categoryName = categoryList[0]
    # Inner for loop
    i = 0
    seedIndex = 0
    # loops through each item in the categoryList
    for categoryItem in categoryList: 
        # if categoryname is the same as the category item, then the index is stored in seedIndex
        if categoryName == categoryItem: 
            seedIndex = i
        # Edited categories to obtain better seed words 
        if categoryName == "children": 
            #categoryItem == "children"
            categoryName = "child"
            #categoryItem = "child"
        if categoryName == "social_media": 
            categoryName = "multimedia"
        if categoryName == "real_estate": 
            categoryName = "estate"
        if categoryName == "air_travel": 
            categoryName = "fly"
        if categoryName == "competing": 
            categoryName = "competition" 
        i = i + 1
# Access the surrounding words of the category name (5 seed words)
    # when category name doesn't exist 
    if seedIndex == 0: 
        wordsToUse.append(categoryList[seedIndex + 1: seedIndex + 6])
        #print(categoryName)
    # when categoryname is at the end of the list 
    elif seedIndex == len(categoryList) - 1 or seedIndex == len(categoryList) - 2: 
        wordsToUse.append(categoryList[seedIndex - 4: seedIndex + 1])
        #print(categoryName)
    # when categoryname is in position1 or position2 of list 
    elif seedIndex == 1 or seedIndex == 2: 
        wordsToUse.append(categoryList[seedIndex: seedIndex + 5])
        #print(categoryName)
    else: 
        wordsToUse.append(categoryList[seedIndex-2 : seedIndex + 3])
            #print(categoryName)
    #print(wordsToUse)
    #print(categoryName)
    #print(categoryList)
# appends the number 2 to each element in the category list (to differentiate from original wordlist)
myCategories = [str(x) + "2" for x in wordlist]
print(myCategories)
#print(categoryList)
# testing 
#print(wordsToUse[0:5])
#print(wordlist)
# Out:
# ['help2', 'office2', 'dance2', 'money2', 'wedding2', 'domestic_work2', 'sleep2', 'medical_emergency2', 'cold2', 'hate2', 'cheerfulness2', 'aggression2', 'occupation2', 'envy2', 'anticipation2', 'family2', 'vacation2', 'crime2', 'attractive2', 'masculine2', 'prison2', 'health2', 'pride2', 'dispute2', 'nervousness2', 'government2', 'weakness2', 'horror2', 'swearing_terms2', 'leisure2', 'suffering2', 'royalty2', 'wealthy2', 'tourism2', 'furniture2', 'school2', 'magic2', 'beach2', 'journalism2', 'morning2', 'banking2', 'social_media2', 'exercise2', 'night2', 'kill2', 'blue_collar_job2', 'art2', 'ridicule2', 'play2', 'computer2', 'college2', 'optimism2', 'stealing2', 'real_estate2', 'home2', 'divine2', 'sexual2', 'fear2', 'irritability2', 'superhero2', 'business2', 'driving2', 'pet2', 'childish2', 'cooking2', 'exasperation2', 'religion2', 'hipster2', 'internet2', 'surprise2', 'reading2', 'worship2', 'leader2', 'independence2', 'movement2', 'body2', 'noise2', 'eating2', 'medieval2', 'zest2', 'confusion2', 'water2', 'sports2', 'death2', 'healing2', 'legend2', 'heroic2', 'celebration2', 'restaurant2', 'violence2', 'programming2', 'dominant_heirarchical2', 'military2', 'neglect2', 'swimming2', 'exotic2', 'love2', 'hiking2', 'communication2', 'hearing2', 'order2', 'sympathy2', 'hygiene2', 'weather2', 'anonymity2', 'trust2', 'ancient2', 'deception2', 'fabric2', 'air_travel2', 'fight2', 'dominant_personality2', 'music2', 'vehicle2', 'politeness2', 'toy2', 'farming2', 'meeting2', 'war2', 'speaking2', 'listen2', 'urban2', 'shopping2', 'disgust2', 'fire2', 'tool2', 'phone2', 'gain2', 'sound2', 'injury2', 'sailing2', 'rage2', 'science2', 'work2', 'appearance2', 'valuable2', 'warmth2', 'youth2', 'sadness2', 'fun2', 'emotional2', 'joy2', 'affection2', 'traveling2', 'fashion2', 'ugliness2', 'lust2', 'shame2', 'torment2', 'economics2', 'anger2', 'politics2', 'ship2', 'clothing2', 'car2', 'strength2', 'technology2', 'breaking2', 'shape_and_size2', 'power2', 'white_collar_job2', 'animal2', 'party2', 'terrorism2', 'smell2', 'disappointment2', 'poor2', 'plant2', 'pain2', 'beauty2', 'timidity2', 'philosophy2', 'negotiate2', 'negative_emotion2', 'cleaning2', 'messaging2', 'competing2', 'law2', 'friends2', 'payment2', 'achievement2', 'alcohol2', 'liquid2', 'feminine2', 'weapon2', 'children2', 'monster2', 'ocean2', 'giving2', 'contentment2', 'writing2', 'rural2', 'positive_emotion2', 'musical2']

# %%
# Create own categories (using reddit model)
# make sure that myCategories links to the correct words
myZip_object = zip(myCategories, wordsToUse)
#print(list(myZip_object))
for wlist, wordsused in list(myZip_object):
    lexicon.create_category(wlist, wordsused, model = "reddit", size = 100, write = True)
#print(list((myZip_object))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-661a140e1e1f> in <module>
#       4 #print(list(myZip_object))
#       5 for wlist, wordsused in list(myZip_object):
# ----> 6     lexicon.create_category(wlist, wordsused, model = "reddit", size = 100, write = True)
#       7 #print(list((myZip_object))
#
# <ipython-input-2-c2bc9e194db7> in create_category(self, name, seeds, model, size, write)
#      66         return count
#      67     def create_category(self,name,seeds,model="fiction",size=100,write=True):
# ---> 68         resp = requests.post(self.backend_url + "/create_category", json={"terms":seeds,"size":size,"model":model})
#      69         #return(resp.text)
#      70         #print(resp.text)
#
# ~/.local/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~/.local/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     392                 conn.request_chunked(method, url, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#     396         # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#
# ~/.local/lib/python3.6/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     232         if "user-agent" not in (six.ensure_str(k.lower()) for k in headers):
#     233             headers["User-Agent"] = _get_default_user_agent()
# --> 234         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     235
#     236     def request_chunked(self, method, url, body=None, headers=None):
#
# /cm/shared/spack/opt/spack/linux-rhel7-x86_64/gcc-4.8.5/python-3.6.3-jaapiswyomewtlo5ngyxtdaorzddg7pf/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /cm/shared/spack/opt/spack/linux-rhel7-x86_64/gcc-4.8.5/python-3.6.3-jaapiswyomewtlo5ngyxtdaorzddg7pf/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# /cm/shared/spack/opt/spack/linux-rhel7-x86_64/gcc-4.8.5/python-3.6.3-jaapiswyomewtlo5ngyxtdaorzddg7pf/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# /cm/shared/spack/opt/spack/linux-rhel7-x86_64/gcc-4.8.5/python-3.6.3-jaapiswyomewtlo5ngyxtdaorzddg7pf/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# /cm/shared/spack/opt/spack/linux-rhel7-x86_64/gcc-4.8.5/python-3.6.3-jaapiswyomewtlo5ngyxtdaorzddg7pf/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# ~/.local/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     198
#     199     def connect(self):
# --> 200         conn = self._new_conn()
#     201         self._prepare_conn(conn)
#     202
#
# ~/.local/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
#     169             conn = connection.create_connection(
# --> 170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#     172
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84             if source_address:
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#      88
#
# KeyboardInterrupt:

# %%
print(wordlist)
# Out:
# ['help', 'office', 'dance', 'money', 'wedding', 'domestic_work', 'sleep', 'medical_emergency', 'cold', 'hate', 'cheerfulness', 'aggression', 'occupation', 'envy', 'anticipation', 'family', 'vacation', 'crime', 'attractive', 'masculine', 'prison', 'health', 'pride', 'dispute', 'nervousness', 'government', 'weakness', 'horror', 'swearing_terms', 'leisure', 'suffering', 'royalty', 'wealthy', 'tourism', 'furniture', 'school', 'magic', 'beach', 'journalism', 'morning', 'banking', 'social_media', 'exercise', 'night', 'kill', 'blue_collar_job', 'art', 'ridicule', 'play', 'computer', 'college', 'optimism', 'stealing', 'real_estate', 'home', 'divine', 'sexual', 'fear', 'irritability', 'superhero', 'business', 'driving', 'pet', 'childish', 'cooking', 'exasperation', 'religion', 'hipster', 'internet', 'surprise', 'reading', 'worship', 'leader', 'independence', 'movement', 'body', 'noise', 'eating', 'medieval', 'zest', 'confusion', 'water', 'sports', 'death', 'healing', 'legend', 'heroic', 'celebration', 'restaurant', 'violence', 'programming', 'dominant_heirarchical', 'military', 'neglect', 'swimming', 'exotic', 'love', 'hiking', 'communication', 'hearing', 'order', 'sympathy', 'hygiene', 'weather', 'anonymity', 'trust', 'ancient', 'deception', 'fabric', 'air_travel', 'fight', 'dominant_personality', 'music', 'vehicle', 'politeness', 'toy', 'farming', 'meeting', 'war', 'speaking', 'listen', 'urban', 'shopping', 'disgust', 'fire', 'tool', 'phone', 'gain', 'sound', 'injury', 'sailing', 'rage', 'science', 'work', 'appearance', 'valuable', 'warmth', 'youth', 'sadness', 'fun', 'emotional', 'joy', 'affection', 'traveling', 'fashion', 'ugliness', 'lust', 'shame', 'torment', 'economics', 'anger', 'politics', 'ship', 'clothing', 'car', 'strength', 'technology', 'breaking', 'shape_and_size', 'power', 'white_collar_job', 'animal', 'party', 'terrorism', 'smell', 'disappointment', 'poor', 'plant', 'pain', 'beauty', 'timidity', 'philosophy', 'negotiate', 'negative_emotion', 'cleaning', 'messaging', 'competing', 'law', 'friends', 'payment', 'achievement', 'alcohol', 'liquid', 'feminine', 'weapon', 'children', 'monster', 'ocean', 'giving', 'contentment', 'writing', 'rural', 'positive_emotion', 'musical']

# %%
print(myCategories)
# Out:
# ['help2', 'office2', 'dance2', 'money2', 'wedding2', 'domestic_work2', 'sleep2', 'medical_emergency2', 'cold2', 'hate2', 'cheerfulness2', 'aggression2', 'occupation2', 'envy2', 'anticipation2', 'family2', 'vacation2', 'crime2', 'attractive2', 'masculine2', 'prison2', 'health2', 'pride2', 'dispute2', 'nervousness2', 'government2', 'weakness2', 'horror2', 'swearing_terms2', 'leisure2', 'suffering2', 'royalty2', 'wealthy2', 'tourism2', 'furniture2', 'school2', 'magic2', 'beach2', 'journalism2', 'morning2', 'banking2', 'social_media2', 'exercise2', 'night2', 'kill2', 'blue_collar_job2', 'art2', 'ridicule2', 'play2', 'computer2', 'college2', 'optimism2', 'stealing2', 'real_estate2', 'home2', 'divine2', 'sexual2', 'fear2', 'irritability2', 'superhero2', 'business2', 'driving2', 'pet2', 'childish2', 'cooking2', 'exasperation2', 'religion2', 'hipster2', 'internet2', 'surprise2', 'reading2', 'worship2', 'leader2', 'independence2', 'movement2', 'body2', 'noise2', 'eating2', 'medieval2', 'zest2', 'confusion2', 'water2', 'sports2', 'death2', 'healing2', 'legend2', 'heroic2', 'celebration2', 'restaurant2', 'violence2', 'programming2', 'dominant_heirarchical2', 'military2', 'neglect2', 'swimming2', 'exotic2', 'love2', 'hiking2', 'communication2', 'hearing2', 'order2', 'sympathy2', 'hygiene2', 'weather2', 'anonymity2', 'trust2', 'ancient2', 'deception2', 'fabric2', 'air_travel2', 'fight2', 'dominant_personality2', 'music2', 'vehicle2', 'politeness2', 'toy2', 'farming2', 'meeting2', 'war2', 'speaking2', 'listen2', 'urban2', 'shopping2', 'disgust2', 'fire2', 'tool2', 'phone2', 'gain2', 'sound2', 'injury2', 'sailing2', 'rage2', 'science2', 'work2', 'appearance2', 'valuable2', 'warmth2', 'youth2', 'sadness2', 'fun2', 'emotional2', 'joy2', 'affection2', 'traveling2', 'fashion2', 'ugliness2', 'lust2', 'shame2', 'torment2', 'economics2', 'anger2', 'politics2', 'ship2', 'clothing2', 'car2', 'strength2', 'technology2', 'breaking2', 'shape_and_size2', 'power2', 'white_collar_job2', 'animal2', 'party2', 'terrorism2', 'smell2', 'disappointment2', 'poor2', 'plant2', 'pain2', 'beauty2', 'timidity2', 'philosophy2', 'negotiate2', 'negative_emotion2', 'cleaning2', 'messaging2', 'competing2', 'law2', 'friends2', 'payment2', 'achievement2', 'alcohol2', 'liquid2', 'feminine2', 'weapon2', 'children2', 'monster2', 'ocean2', 'giving2', 'contentment2', 'writing2', 'rural2', 'positive_emotion2', 'musical2']

# %%
# test run
print(myCategories[0], wordsToUse[0])
# Out:
# help2 ['chore', 'responsible', 'help', 'grateful', 'maid']

# %%
lexicon.cats
# Out:
# defaultdict(list,
#             {'help': ['encourage',
#               'obligation',
#               'protect',
#               'help',
#               'aide',
#               'nurse',
#               'maid',
#               'responsible',
#               'counsel',
#               'stabilize',
#               'duty',
#               'rely',
#               'generously',
#               'financial',
#               'guide',
#               'patient',
#               'tend',
#               'advisor',
#               'prepare',
#               'kindly',
#               'benefit',
#               'helpful',
#               'assist',
#               'servant',
#               'volunteer',
#               'favor',
#               'crutch',
#               'friend',
#               'advise',
#               'wheelchair',
#               'provide',
#               'support',
#               'oversee',
#               'carry',
#               'cooperate',
#               'supportive',
#               'entrust',
#               'chore',
#               'assistance',
#               'treat',
#               'helper',
#               'housework',
#               'hospitality',
#               'rescue',
#               'promote',
#               'escort',
#               'serve',
#               'protection',
#               'housekeeping',
#               'encouragement',
#               'offer',
#               'request',
#               'trust',
#               'honor',
#               'temporary',
#               'nursing',
#               'aid',
#               'grateful'],
#              'office': ['computer',
#               'paperwork',
#               'intercom',
#               'meeting',
#               'administrator',
#               'accounting',
#               'setup',
#               'organizing',
#               'spreadsheet',
#               'scheduling',
#               'supervisor',
#               'organize',
#               'briefing',
#               'registration',
#               'presentation',
#               'headquarters',
#               'workstation',
#               'tutor',
#               'manager',
#               'office',
#               'reception',
#               'handbook',
#               'organizer',
#               'projector',
#               'secretary',
#               'timetable',
#               'consultation',
#               'advisor',
#               'copier',
#               'bookshelf',
#               'workplace',
#               'roster',
#               'informational',
#               'application',
#               'laptop',
#               'cubicle',
#               'pager',
#               'fax',
#               'typing',
#               'tablet',
#               'agenda',
#               'backroom',
#               'keyboard',
#               'record',
#               'folder',
#               'colleague',
#               'marketing',
#               'memo',
#               'booking',
#               'clipboard',
#               'table',
#               'therapist',
#               'conference',
#               'file',
#               'desktop',
#               'director',
#               'briefcase',
#               'boardroom',
#               'attendance',
#               'program',
#               'blueprint',
#               'room',
#               'typewriter',
#               'planner',
#               'staff',
#               'registrar',
#               'receptionist',
#               'client',
#               'programming',
#               'document',
#               'lecture',
#               'notify',
#               'consultant',
#               'technician',
#               'assist',
#               'employee',
#               'building',
#               'assistant',
#               'administration',
#               'printing',
#               'binder',
#               'counsellor',
#               'interview',
#               'administrative',
#               'chair',
#               'desk',
#               'schedule',
#               'information',
#               'archive',
#               'supervise'],
#              'dance': ['song',
#               'jukebox',
#               'club',
#               'ballroom',
#               'practicing',
#               'twirl',
#               'waltz',
#               'accompaniment',
#               'spotlight',
#               'gymnastics',
#               'rehearsal',
#               'freestyle',
#               'tap',
#               'cheer',
#               'chord',
#               'choreographer',
#               'bounce',
#               'contemporary',
#               'performance',
#               'motion',
#               'sway',
#               'glee',
#               'ballet',
#               'musical',
#               'recital',
#               'acrobatic',
#               'turns',
#               'studio',
#               'choreography',
#               'performer',
#               'speaker',
#               'radio',
#               'rock',
#               'tune',
#               'entertain',
#               'classic',
#               'pianist',
#               'rehearsing',
#               'musician',
#               'rapping',
#               'twirling',
#               'bohemian',
#               'melodic',
#               'partying',
#               'dancer',
#               'drum',
#               'perform',
#               'rave',
#               'strut',
#               'bop',
#               'classical',
#               'disco',
#               'swinging',
#               'band',
#               'footwork',
#               'grind',
#               'practice',
#               'choir',
#               'guitar',
#               'swaying',
#               'rehearse',
#               'ballad',
#               'sync',
#               'cd',
#               'gymnastic',
#               'burlesque',
#               'hypnotic',
#               'music',
#               'ballerina',
#               'solo',
#               'stage',
#               'rhythmic',
#               'techno',
#               'upbeat',
#               'jaunty',
#               'chorus',
#               'hip',
#               'jazz',
#               'dj',
#               'dancing',
#               'acrobatics',
#               'medley',
#               'onstage',
#               'dance',
#               'rendition'],
#              'money': ['mortgage',
#               'bargain',
#               'cash',
#               'buying',
#               'euro',
#               'buck',
#               'cent',
#               'worth',
#               'financial',
#               'costly',
#               'debit',
#               'gambling',
#               'rupee',
#               'credit',
#               'funding',
#               'payment',
#               'invest',
#               'paying',
#               'buyer',
#               'income',
#               'coin',
#               'loan',
#               'count',
#               'earnings',
#               'salary',
#               'money',
#               'yen',
#               'retail',
#               'bidding',
#               'ransom',
#               'revenue',
#               'purchase',
#               'nickel',
#               'cost',
#               'repay',
#               'checkbook',
#               'voucher',
#               'donation',
#               'merchandise',
#               'expensive',
#               'trade',
#               'saving',
#               'splurge',
#               'bail',
#               'coupon',
#               'debt',
#               'bill',
#               'bank',
#               'bankruptcy',
#               'allowance',
#               'prize',
#               'gamble',
#               'payday',
#               'inheritance',
#               'donate',
#               'quid',
#               'pension',
#               'treasury',
#               'currency',
#               'deduct',
#               'seller',
#               'banking',
#               'price',
#               'receipt',
#               'millionaire',
#               'bribe',
#               'banker',
#               'repayment',
#               'owe',
#               'wad',
#               'hundred',
#               'paycheck',
#               'profit',
#               'monetary',
#               'membership',
#               'dime',
#               'change',
#               'pricey',
#               'budget',
#               'franc',
#               'buy',
#               'tax',
#               'fortune',
#               'sale',
#               'dollar',
#               'employment',
#               'peso',
#               'wallet',
#               'finance',
#               'paid',
#               'compensation',
#               'discount',
#               'trillion',
#               'rent',
#               'cheque',
#               'deposit',
#               'lottery',
#               'drachma',
#               'reward',
#               'pay',
#               'wage',
#               'investment',
#               'mint',
#               'shilling',
#               'employee',
#               'clerk',
#               'fund'],
#              'wedding': ['pledge',
#               'honeymoon',
#               'wed',
#               'announce',
#               'faithful',
#               'propose',
#               'vow',
#               'celebrate',
#               'romantically',
#               'newlywed',
#               'priest',
#               'dowry',
#               'commemorate',
#               'engagement',
#               'spouse',
#               'marry',
#               'ceremony',
#               'officially',
#               'reception',
#               'arrange',
#               'vicar',
#               'family',
#               'cherish',
#               'planning',
#               'promise',
#               'lawful',
#               'son',
#               'husband',
#               'caterer',
#               'congratulation',
#               'official',
#               'prospective',
#               'jeweler',
#               'groom',
#               'bonding',
#               'anniversary',
#               'altar',
#               'church',
#               'wife',
#               'commitment',
#               'pronounce',
#               'declare',
#               'married',
#               'girlfriend',
#               'relationship',
#               'agree',
#               'wedding',
#               'inheritance',
#               'party',
#               'tuxedo',
#               'wedlock',
#               'debutante',
#               'marital',
#               'plan',
#               'fiancee',
#               'bride',
#               'lawfully',
#               'finalize',
#               'gift',
#               'beloved',
#               'engaged',
#               'someday',
#               'suitor',
#               'prince',
#               'planner',
#               'cancel',
#               'invite',
#               'overjoyed',
#               'courtship',
#               'ring',
#               'ecstatic',
#               'proposal',
#               'finance',
#               'wedded',
#               'oldest',
#               'remarry',
#               'arranged',
#               'invitation',
#               'rejoice',
#               'in-law',
#               'valentine',
#               'appointment',
#               'stepson',
#               'celebration',
#               'divorced',
#               'engage',
#               'boyfriend',
#               'pact',
#               'happy',
#               'tradition',
#               'honor',
#               'marriage',
#               'dutiful',
#               'vacation'],
#              'domestic_work': ['nanny',
#               'morning',
#               'clean',
#               'chef',
#               'kitchen',
#               'job',
#               'home',
#               'scrubbing',
#               'scrub',
#               'organizing',
#               'errand',
#               'sitter',
#               'cleaning',
#               'parent',
#               'dishwasher',
#               'vacuum',
#               'organize',
#               'mum',
#               'washer',
#               'tidy',
#               'cleaner',
#               'cleaned',
#               'spotless',
#               'house',
#               'bake',
#               'cook',
#               'remodeling',
#               'bathroom',
#               'mom',
#               'housekeeper',
#               'cooking',
#               'chore',
#               'baking',
#               'wash',
#               'serve',
#               'housekeeping',
#               'meal',
#               'laundry',
#               'family',
#               'washing',
#               'housework'],
#              'sleep': ['wakeup',
#               'morning',
#               'relax',
#               'asleep',
#               'tonight',
#               'sleepy',
#               'lazily',
#               'blanket',
#               'hammock',
#               'slumber',
#               'tiring',
#               'yawning',
#               'undisturbed',
#               'peaceful',
#               'cushion',
#               'awoke',
#               'tired',
#               'awaken',
#               'sleepless',
#               'half',
#               'hotel',
#               'lull',
#               'nightmare',
#               'napping',
#               'dream',
#               'laying',
#               'bedtime',
#               'rest',
#               'resting',
#               'exhaustion',
#               'sheet',
#               'bedding',
#               'crib',
#               'sleeping',
#               'exhausted',
#               'sleep',
#               'quilt',
#               'lazy',
#               'nap',
#               'comfort',
#               'comfortably',
#               'slept',
#               'settle',
#               'nighttime',
#               'dreaming',
#               'bed',
#               'dreamt',
#               'mattress',
#               'lay',
#               'snoring',
#               'bedroom',
#               'pillow'],
#              'medical_emergency': ['seizure',
#               'rehab',
#               'morphine',
#               'intensive',
#               'antibiotic',
#               'nurse',
#               'recover',
#               'medic',
#               'die',
#               'unconscious',
#               'sick',
#               'accident',
#               'deathbed',
#               'injection',
#               'breakdown',
#               'diagnosis',
#               'severe',
#               'hospital',
#               'fever',
#               'pharmacy',
#               'epilepsy',
#               'ambulance',
#               'schizophrenic',
#               'stitch',
#               'doctor',
#               'overdose',
#               'emergency',
#               'tumor',
#               'unwell',
#               'unresponsive',
#               'stroke',
#               'transfusion',
#               'flu',
#               'hemorrhage',
#               'health',
#               'relapse',
#               'surgery',
#               'medication',
#               'transplant',
#               'childbirth',
#               'wheelchair',
#               '911',
#               'diabetes',
#               'stretcher',
#               'miscarriage',
#               'lifeless',
#               'revive',
#               'gurney',
#               'resuscitate',
#               'treatment',
#               'birth',
#               'symptom',
#               'coma',
#               'bedridden',
#               'leukemia',
#               'ward',
#               'comatose',
#               'ventilator',
#               'sickness',
#               'anesthetic',
#               'panic',
#               'anesthesia',
#               'medical',
#               'paralysis',
#               'physician',
#               'premature',
#               'injured',
#               'pregnant',
#               'pancreatic',
#               'sedative',
#               'illness',
#               'pneumonia',
#               'cardiac',
#               'contraction',
#               'terminal',
#               'injury',
#               'operating',
#               'concussion',
#               'infection',
#               'paralyze',
#               'examination',
#               'labor',
#               'complication',
#               'cancerous',
#               'bleed',
#               'injure',
#               'schizophrenia',
#               'disease',
#               'diagnose',
#               'limp',
#               'condition',
#               'biopsy',
#               'bandaged',
#               'aneurysm',
#               'patient',
#               'tuberculosis',
#               'blackout',
#               'medically',
#               'surgeon',
#               'painkiller',
#               'coroner',
#               'bleeding',
#               'trauma',
#               'infirmary',
#               'paramedic',
#               'cancer',
#               'morgue',
#               'swelling',
#               'defibrillator'],
#              'cold': ['numb',
#               'shawl',
#               'solstice',
#               'wet',
#               'chilling',
#               'frost',
#               'gust',
#               'glacier',
#               'cooler',
#               'snowball',
#               'dreary',
#               'soak',
#               'feel',
#               'air',
#               'freeze',
#               'freezing',
#               'bitterly',
#               'nip',
#               'outside',
#               'frostbite',
#               'snowfall',
#               'chilled',
#               'cool',
#               'overcast',
#               'touch',
#               'arctic',
#               'snowy',
#               'blister',
#               'cold',
#               'coat',
#               'shiver',
#               'chilly',
#               'drizzle',
#               'wintry',
#               'cooling',
#               'woolly',
#               'cloak',
#               'winter',
#               'insulate',
#               'hypothermia',
#               'nipping',
#               'torrential',
#               'coolness',
#               'icy',
#               'froze',
#               'windy',
#               'brisk',
#               'breeze',
#               'ice',
#               'frigid',
#               'crisp',
#               'colder',
#               'shivers',
#               'damp',
#               'chill',
#               'snowing',
#               'bitter',
#               'temperature',
#               'snowstorm',
#               'frosty',
#               'glacial',
#               'shivering',
#               'climate',
#               'blizzard',
#               'weather',
#               'snow',
#               'sweater',
#               'slush',
#               'sleet'],
#              'hate': ['pathetic',
#               'horrid',
#               'rant',
#               'suffering',
#               'taunt',
#               'despicable',
#               'meanness',
#               'dislike',
#               'loath',
#               'disrespectful',
#               'irritate',
#               'jealous',
#               'seriously',
#               'scum',
#               'disrespect',
#               'worthless',
#               'jealously',
#               'frustrating',
#               'accusation',
#               'hurtful',
#               'cruel',
#               'unreasonable',
#               'unfairness',
#               'rude',
#               'degrade',
#               'venomous',
#               'sexist',
#               'hating',
#               'mistrust',
#               'disgusting',
#               'awful',
#               'selfishness',
#               'belittle',
#               'disgust',
#               'terrible',
#               'insensitive',
#               'selfish',
#               'repulsive',
#               'ignore',
#               'infuriate',
#               'degrading',
#               'unhappiness',
#               'insult',
#               'resent',
#               'kill',
#               'guilt',
#               'rage',
#               'loathe',
#               'despise',
#               'humiliate',
#               'vindictive',
#               'envy',
#               'betray',
#               'horrible',
#               'bullying',
#               'bully',
#               'vengeful',
#               'hypocrite',
#               'worse',
#               'heartless',
#               'blame',
#               'harsh',
#               'nasty',
#               'detest',
#               'spat',
#               'offend',
#               'hateful',
#               'distrust',
#               'negativity',
#               'emotion',
#               'rejection',
#               'idiotic',
#               'judgmental',
#               'despised',
#               'loathing',
#               'contempt',
#               'feeling',
#               'resentment',
#               'unkind',
#               'annoying',
#               'murderous',
#               'mad',
#               'humiliation',
#               'miserable',
#               'racism',
#               'frustrate',
#               'betrayed',
#               'anger',
#               'scorn',
#               'betrayal',
#               'angry',
#               'unhappy',
#               'ridicule',
#               'hate',
#               'bad',
#               'hated',
#               'hatred',
#               'discriminate',
#               'cruelty',
#               'ashamed',
#               'animosity'],
#              'cheerfulness': ['elation',
#               'clap',
#               'amazement',
#               'zealous',
#               'euphoric',
#               'delightfully',
#               'happily',
#               'uplifting',
#               'blissful',
#               'ecstatic',
#               'lively',
#               'excitement',
#               'triumphantly',
#               'applause',
#               'contented',
#               'spontaneity',
#               'glory',
#               'sweetness',
#               'exhilaration',
#               'cheer',
#               'pride',
#               'jovial',
#               'happiness',
#               'cheering',
#               'awed',
#               'clapping',
#               'delighted',
#               'rejoice',
#               'cheerfully',
#               'contagious',
#               'optimism',
#               'fondness',
#               'gleeful',
#               'euphoria',
#               'contentment',
#               'delight',
#               'emotion',
#               'cheerful',
#               'satisfaction',
#               'victorious',
#               'astonishment',
#               'energetically',
#               'determination',
#               'glee',
#               'cheerfulness',
#               'gratitude',
#               'gleefully',
#               'enjoyment',
#               'bask',
#               'adoration',
#               'joyful',
#               'beaming',
#               'eagerness',
#               'positively',
#               'laughter',
#               'enthusiastically',
#               'bliss',
#               'elated',
#               'cheery',
#               'heartfelt',
#               'friendliness',
#               'unrestrained',
#               'boisterous',
#               'buoyant',
#               'enthusiastic',
#               'exuberant',
#               'surprise',
#               'triumph',
#               'amusement',
#               'happy',
#               'joy',
#               'jubilant',
#               'pleasure',
#               'certainty',
#               'exuberance',
#               'appreciation',
#               'giddy',
#               'joyous',
#               'enthusiasm',
#               'overjoyed',
#               'thrill',
#               'triumphant'],
#              'aggression': ['wildness',
#               'meanness',
#               'ferocious',
#               'ferocity',
#               'unrelenting',
#               'incite',
#               'furious',
#               'spite',
#               'violence',
#               'aggressive',
#               'aggression',
#               'resentful',
#               'intent',
#               'bravado',
#               'intimidating',
#               'savage',
#               'lethal',
#               'defend',
#               'predatory',
#               'attack',
#               'irate',
#               'quash',
#               'authoritative',
#               'temper',
#               'hostile',
#               'defiance',
#               'belittle',
#               'brazen',
#               'threatening',
#               'endanger',
#               'brute',
#               'overconfident',
#               'bloodthirsty',
#               'infuriate',
#               'insult',
#               'fear',
#               'feral',
#               'kill',
#               'provoke',
#               'menacing',
#               'ruthlessness',
#               'rage',
#               'aggressor',
#               'fearsome',
#               'barbaric',
#               'assertive',
#               'warn',
#               'defiant',
#               'seething',
#               'aggressiveness',
#               'ruthlessly',
#               'intimidation',
#               'menace',
#               'betray',
#               'dominate',
#               'vengeful',
#               'strong',
#               'dangerous',
#               'ruthless',
#               'harsh',
#               'outburst',
#               'audacity',
#               'unfazed',
#               'deadly',
#               'brutality',
#               'angered',
#               'offend',
#               'hateful',
#               'intensity',
#               'brutal',
#               'overpower',
#               'confrontational',
#               'force',
#               'demeaning',
#               'provocation',
#               'violent',
#               'fight',
#               'snarl',
#               'harass',
#               'intimidated',
#               'contempt',
#               'resentment',
#               'vicious',
#               'maim',
#               'agitated',
#               'intimidate',
#               'cockiness',
#               'murderous',
#               'threatened',
#               'suppress',
#               'hostility',
#               'sadistic',
#               'confront',
#               'volatile',
#               'harshness',
#               'destructive',
#               'malicious',
#               'anger',
#               'malice',
#               'brash',
#               'threaten',
#               'domineering',
#               'belligerent',
#               'angry',
#               'territorial',
#               'retaliation',
#               'masculinity',
#               'fearful',
#               'infuriated',
#               'threat',
#               'hatred',
#               'cruelty',
#               'livid',
#               'fierce',
#               'outrage',
#               'undermine',
#               'animosity'],
#              'occupation': ['journalist',
#               'officer',
#               'chef',
#               'nurse',
#               'retire',
#               'pharmacist',
#               'retirement',
#               'job',
#               'qualified',
#               'supervise',
#               'accounting',
#               'entrepreneur',
#               'accountant',
#               'supervisor',
#               'lawyer',
#               'qualification',
#               'interpreter',
#               'senator',
#               'florist',
#               'professional',
#               'manager',
#               'office',
#               'hairdresser',
#               'doctor',
#               'inspector',
#               'salary',
#               'secretary',
#               'actor',
#               'bodyguard',
#               'analyst',
#               'hostess',
#               'caterer',
#               'retired',
#               'choreographer',
#               'detective',
#               'intern',
#               'executive',
#               'agent',
#               'workplace',
#               'worker',
#               'concierge',
#               'cashier',
#               'hire',
#               'pediatrician',
#               'workaholic',
#               'waiter',
#               'neurologist',
#               'profession',
#               'working',
#               'maid',
#               'publicist',
#               'attorney',
#               'service',
#               'electrician',
#               'businesswoman',
#               'colleague',
#               'therapist',
#               'politician',
#               'banker',
#               'foreman',
#               'server',
#               'entertainer',
#               'gynecologist',
#               'physician',
#               'bartender',
#               'baker',
#               'psychologist',
#               'catering',
#               'employ',
#               'internship',
#               'waitress',
#               'specialist',
#               'occupation',
#               'psychiatrist',
#               'dentist',
#               'nanny',
#               'receptionist',
#               'employment',
#               'policewoman',
#               'chemist',
#               'policeman',
#               'businessman',
#               'consultant',
#               'surgeon',
#               'technician',
#               'coordinator',
#               'producer',
#               'pediatric',
#               'assistant',
#               'owner',
#               'veterinarian',
#               'photographer',
#               'interview',
#               'housekeeper',
#               'employee',
#               'singer',
#               'clerk'],
#              'envy': ['belittle',
#               'misery',
#               'hostility',
#               'jealousy',
#               'meanness',
#               'yearning',
#               'animosity',
#               'arrogance',
#               'dislike',
#               'hateful',
#               'yearn',
#               'jealous',
#               'flaunt',
#               'resent',
#               'negativity',
#               'ugliness',
#               'annoyance',
#               'determination',
#               'weakness',
#               'jealously',
#               'attraction',
#               'bitterness',
#               'rage',
#               'wealth',
#               'unrequited',
#               'despised',
#               'frustration',
#               'deception',
#               'vindictive',
#               'hate',
#               'envy',
#               'wrath',
#               'resentment',
#               'discontent',
#               'cynicism',
#               'hatred',
#               'disdain',
#               'envious',
#               'passion',
#               'insecurity',
#               'unease',
#               'outrage',
#               'heartache',
#               'ambition',
#               'selfishness'],
#              'anticipation': ['trepidation',
#               'elation',
#               'visibly',
#               'agitation',
#               'tantalizing',
#               'eagerly',
#               'lust',
#               'fervent',
#               'quivering',
#               'perspiration',
#               'excitement',
#               'yearning',
#               'anticipation',
#               'foreboding',
#               'longing',
#               'anticipate',
#               'excite',
#               'eager',
#               'surge',
#               'wildly',
#               'exhilaration',
#               'urgency',
#               'yearn',
#               'quake',
#               'dread',
#               'jittery',
#               'arouse',
#               'adrenalin',
#               'feverishly',
#               'fevered',
#               'readiness',
#               'curiosity',
#               'delight',
#               'contentment',
#               'intensify',
#               'alertness',
#               'throbbing',
#               'frenzy',
#               'quicken',
#               'anxious',
#               'adrenaline',
#               'pumping',
#               'steadily',
#               'impending',
#               'relish',
#               'nervousness',
#               'restlessness',
#               'apprehension',
#               'eagerness',
#               'anxiously',
#               'prospect',
#               'trembling',
#               'anticipated',
#               'overwhelming',
#               'unconsciously',
#               'unsettle',
#               'nervous',
#               'quickening',
#               'aroused',
#               'tremor',
#               'awareness',
#               'tantalizingly',
#               'joy',
#               'uncertainty',
#               'flutter',
#               'apprehensive',
#               'suspense',
#               'intensifies',
#               'giddy',
#               'enthusiasm',
#               'impatience',
#               'thrill',
#               'tremble'],
#              'family': ['visit',
#               'niece',
#               'upbringing',
#               'son',
#               'estranged',
#               'husband',
#               'newborn',
#               'adoptive',
#               'home',
#               'child',
#               'granddaughter',
#               'finance',
#               'leave',
#               'best',
#               'daughter',
#               'adoption',
#               'fiancee',
#               'brother',
#               'aunt',
#               'legacy',
#               'sister',
#               'mommy',
#               'in-law',
#               'parent',
#               'stepfather',
#               'orphaned',
#               'sibling',
#               'grandson',
#               'mother',
#               'foster',
#               'stepdaughter',
#               'wife',
#               'father',
#               'caretaker',
#               'grandparent',
#               'biological',
#               'darling',
#               'mum',
#               'beloved',
#               'baby',
#               'stepmother',
#               'grandmother',
#               'reunion',
#               'childbirth',
#               'loving',
#               'relative',
#               'nephew',
#               'grandfather',
#               'spouse',
#               'dad',
#               'marry',
#               'twin',
#               'mom',
#               'grandkids',
#               'stepson',
#               'divorce',
#               'surrogate',
#               'divorced',
#               'marriage',
#               'godfather',
#               'married',
#               'orphan',
#               'granddaddy',
#               'conceive',
#               'illegitimate',
#               'grandchild',
#               'childhood',
#               'widowed',
#               'parents',
#               'godmother',
#               'heir',
#               'offspring',
#               'matriarch',
#               'adopt',
#               'uncle',
#               'family',
#               'cousin',
#               'biologically',
#               'grandma',
#               'wedlock',
#               'daddy'],
#              'vacation': ['resort',
#               'visit',
#               'adventure',
#               'honeymoon',
#               'secluded',
#               'shore',
#               'journey',
#               'traveling',
#               'accommodation',
#               'hangout',
#               'camping',
#               'condominium',
#               'villa',
#               'outback',
#               'fun',
#               'reservation',
#               'observatory',
#               'outing',
#               'yacht',
#               'yearly',
#               'overnight',
#               'condo',
#               'weekend',
#               'spend',
#               'seashore',
#               'airport',
#               'spending',
#               'outside',
#               'explore',
#               'hotel',
#               'overseas',
#               'museum',
#               'tour',
#               'tropical',
#               'lakeside',
#               'location',
#               'promotion',
#               'hiking',
#               'trip',
#               'inn',
#               'excursion',
#               'campground',
#               'tourist',
#               'nightlife',
#               'coast',
#               'holiday',
#               'seaside',
#               'lake',
#               'venue',
#               'plan',
#               'casino',
#               'landmark',
#               'limo',
#               'waterfront',
#               'surfing',
#               'skiing',
#               'rental',
#               'sightseeing',
#               'abroad',
#               'brochure',
#               'ferry',
#               'coastline',
#               'summer',
#               'coastal',
#               'flight',
#               'ocean',
#               'spa',
#               'destination',
#               'cruise',
#               'lax',
#               'harbor',
#               'suite',
#               'ticket',
#               'rent',
#               'luxurious',
#               'beach',
#               'stay',
#               'restaurant',
#               'countryside',
#               'getaway',
#               'boarding',
#               'packing',
#               'expressway',
#               'inland',
#               'drive',
#               'scenic',
#               'carnival',
#               'hostel',
#               'touring',
#               'travel',
#               'night',
#               'shoreline',
#               'surf',
#               'ride',
#               'nightclub',
#               'upscale',
#               'vacation'],
#              'crime': ['corruption',
#               'captive',
#               'shoplifting',
#               'officer',
#               'condemn',
#               'arrest',
#               'trespass',
#               'commit',
#               'mugging',
#               'forgery',
#               'manhunt',
#               'outlaw',
#               'commission',
#               'motive',
#               'homicide',
#               'unforgivable',
#               'prison',
#               'conspirator',
#               'robber',
#               'violence',
#               'incriminate',
#               'custody',
#               'conspiracy',
#               'precinct',
#               'stealing',
#               'abduct',
#               'illegal',
#               'scene',
#               'unlawful',
#               'rapist',
#               'forensic',
#               'organization',
#               'felony',
#               'burglar',
#               'riot',
#               'ransom',
#               'prostitution',
#               'robbery',
#               'trespassing',
#               'perpetrator',
#               'interrogate',
#               'detective',
#               'victim',
#               'prosecutor',
#               'undercover',
#               'ambush',
#               'harassment',
#               'scam',
#               'treason',
#               'kill',
#               'terrorize',
#               'hostage',
#               'assassination',
#               'investigate',
#               'sentencing',
#               'informant',
#               'arson',
#               'bail',
#               'jury',
#               'enforcement',
#               'crime',
#               'prosecute',
#               'manslaughter',
#               'criminally',
#               'assassinate',
#               'kidnapper',
#               'wrongdoing',
#               'slavery',
#               'prosecution',
#               'kidnapping',
#               'murdering',
#               'ruthless',
#               'execution',
#               'execute',
#               'probation',
#               'bribery',
#               'defendant',
#               'brutality',
#               'infraction',
#               'smuggling',
#               'brutal',
#               'transgression',
#               'apprehend',
#               'fugitive',
#               'culprit',
#               'eyewitness',
#               'vigilante',
#               'criminal',
#               'trafficking',
#               'heinous',
#               'allegedly',
#               'fraud',
#               'slaughter',
#               'assassin',
#               'flee',
#               'conspire',
#               'heist',
#               'suspect',
#               'report',
#               'felon',
#               'whereabouts',
#               'cartel',
#               'convict',
#               'maim',
#               'offender',
#               'trial',
#               'courtroom',
#               'investigator',
#               'cop',
#               'killer',
#               'swindle',
#               'authorities',
#               'assault',
#               'kidnap',
#               'bombing',
#               'notorious',
#               'massacre',
#               'accuse',
#               'exile',
#               'killing',
#               'law',
#               'imprison',
#               'thief',
#               'genocide',
#               'disappearance',
#               'rape',
#               'policeman',
#               'gruesome',
#               'dealer',
#               'interrogation',
#               'testify',
#               'rob',
#               'inmate',
#               'mastermind',
#               'blackmail',
#               'burglary',
#               'domestic',
#               'corrupt',
#               'abduction',
#               'prisoner',
#               'mobster',
#               'murder',
#               'theft',
#               'alleged',
#               'terrorist',
#               'citizen',
#               'witness',
#               'unspeakable',
#               'investigation',
#               'terrorism',
#               'imprisonment',
#               'warrant',
#               'vandalism',
#               'murderer',
#               'atrocity',
#               'accomplice',
#               'cruelty',
#               'gambler'],
#              'attractive': ['supermodel',
#               'irresistible',
#               'fantasize',
#               'revealing',
#               'photogenic',
#               'appealing',
#               'athletic',
#               'enticing',
#               'dimpled',
#               'handsome',
#               'marvelous',
#               'attractiveness',
#               'dazzle',
#               'fascinating',
#               'beauty',
#               'masculine',
#               'appeal',
#               'hunky',
#               'sexy',
#               'adore',
#               'attractively',
#               'swoon',
#               'classically',
#               'adorable',
#               'lovable',
#               'physique',
#               'seductive',
#               'strikingly',
#               'lovely',
#               'captivating',
#               'mesmerizing',
#               'charmer',
#               'cute',
#               'gorgeous',
#               'dreamy',
#               'envious',
#               'provocative',
#               'breathtaking',
#               'tanned',
#               'attract',
#               'buff',
#               'popular',
#               'dashing',
#               'fantastic',
#               'dazzling',
#               'curvy',
#               'blonde',
#               'coolest',
#               'perfect',
#               'fabulous',
#               'enchanting',
#               'admire',
#               'breathtakingly',
#               'pleasing',
#               'desirable',
#               'pretty',
#               'attracted',
#               'beautiful',
#               'fashionable',
#               'sexiest',
#               'beautifully',
#               'luscious',
#               'glamorous',
#               'charmingly',
#               'looking',
#               'sassy',
#               'attractive',
#               'compliment',
#               'impress',
#               'angelic',
#               'flatter',
#               'hotter',
#               'tempting',
#               'stunning',
#               'stylish',
#               'toned',
#               'alluring',
#               'built',
#               'flawless',
#               'inviting',
#               'hunk',
#               'charming',
#               'hot',
#               'charismatic',
#               'feminine',
#               'chiseled'],
#              'masculine': ['boys',
#               'stocky',
#               'hormone',
#               'masculine',
#               'hunky',
#               'appeal',
#               'stature',
#               'tattooed',
#               'scruffy',
#               'authority',
#               'arrogance',
#               'lad',
#               'stereotypical',
#               'attractively',
#               'dude',
#               'bulky',
#               'beefy',
#               'manly',
#               'egotistical',
#               'rugged',
#               'testosterone',
#               'athletic',
#               'distinct',
#               'aggressive',
#               'physique',
#               'handsome',
#               'baritone',
#               'hormonal',
#               'boy',
#               'domineering',
#               'shouldered',
#               'alluring',
#               'brawny',
#               'brutish',
#               'attractiveness',
#               'fella',
#               'figure',
#               'jock',
#               'masculinity',
#               'cocky',
#               'male',
#               'intimidating',
#               'biceps',
#               'burly',
#               'dreamy',
#               'dominate',
#               'surfer',
#               'puberty',
#               'guy',
#               'muscular',
#               'hunk',
#               'athletically',
#               'rowdy',
#               'overpowering',
#               'intimidate',
#               'youthful',
#               'cockiness',
#               'strong',
#               'mentality',
#               'man',
#               'males',
#               'attract',
#               'charisma',
#               'bodied',
#               'chiseled'],
#              'prison': ['vault',
#               'torture',
#               'authorities',
#               'shootout',
#               'captive',
#               'lock',
#               'execution',
#               'officer',
#               'outpost',
#               'blockade',
#               'capture',
#               'arrest',
#               'sentry',
#               'charge',
#               'jailhouse',
#               'ward',
#               'imprison',
#               'guard',
#               'platoon',
#               'policeman',
#               'confinement',
#               'chain',
#               'cage',
#               'occupant',
#               'cuffed',
#               'ambush',
#               'interrogation',
#               'dungeon',
#               'citadel',
#               'confine',
#               'inmate',
#               'secure',
#               'kill',
#               'chamber',
#               'apprehend',
#               'prison',
#               'hostage',
#               'burglary',
#               'prisoner',
#               'investigate',
#               'sentencing',
#               'guards',
#               'penitentiary',
#               'compound',
#               'informant',
#               'criminal',
#               'walled',
#               'cell',
#               'bail',
#               'trooper',
#               'locked',
#               'patrol',
#               'escaped',
#               'warden',
#               'gate',
#               'perimeter',
#               'abduct',
#               'enforcer',
#               'escape',
#               'manslaughter',
#               'imprisonment',
#               'underground',
#               'executioner',
#               'containment',
#               'jail',
#               'vandalism',
#               'murderer',
#               'convict',
#               'facility',
#               'overseer',
#               'trial',
#               'escort',
#               'surveillance',
#               'restrain',
#               'correctional',
#               'secured',
#               'security',
#               'barricade',
#               'cop',
#               'patrolling',
#               'gatekeeper',
#               'captivity',
#               'confiscate'],
#              'health': ['seizure',
#               'arthritis',
#               'rehab',
#               'stress',
#               'vet',
#               'antibiotic',
#               'nurse',
#               'syndrome',
#               'pharmacist',
#               'recovery',
#               'depression',
#               'vomiting',
#               'sick',
#               'diabetic',
#               'diet',
#               'injection',
#               'influenza',
#               'diagnosis',
#               'disorder',
#               'med',
#               'severe',
#               'chronic',
#               'immune',
#               'psychological',
#               'hospital',
#               'discharge',
#               'fever',
#               'pharmacy',
#               'epilepsy',
#               'depressant',
#               'schizophrenic',
#               'doctor',
#               'tumor',
#               'dementia',
#               'unwell',
#               'antidote',
#               'malnutrition',
#               'chemotherapy',
#               'vitamin',
#               'liver',
#               'transfusion',
#               'rehabilitation',
#               'flu',
#               'dehydration',
#               'health',
#               'testing',
#               'relapse',
#               'anxiety',
#               'sufferer',
#               'respiratory',
#               'poisoning',
#               'pills',
#               'surgery',
#               'medication',
#               'transplant',
#               'anorexia',
#               'clinic',
#               'nutrition',
#               'relievers',
#               'remission',
#               'cramp',
#               'diabetes',
#               'kidney',
#               'mental',
#               'trimester',
#               'dental',
#               'checkup',
#               'allergy',
#               'miscarriage',
#               'pediatrician',
#               'treatment',
#               'maternity',
#               'medicine',
#               'malaria',
#               'ultrasound',
#               'nursing',
#               'symptom',
#               'vaccine',
#               'neurologist',
#               'coma',
# ...
#               'beach',
#               'speed_boat',
#               'houseboat',
#               'little_boat',
#               'sea_wall',
#               'sailing',
#               'lagoon',
#               'speedboat',
#               'upwind',
#               'sail',
#               'sailboats',
#               'jetski',
#               'swam',
#               'canoe',
#               'shoreline',
#               'beached',
#               'little_boats',
#               'marina',
#               'open_sea'],
#              'giving2': ['extra_funds',
#               'promising',
#               'financial_support',
#               'government_funding',
#               'additional_funding',
#               'other_incentives',
#               'funding',
#               'personal_support',
#               'direct_payment',
#               'giving',
#               'hand-outs',
#               'additional_money',
#               'provide',
#               'free_care',
#               'financial_incentives',
#               'tax_receipt',
#               'free_money',
#               'assistance',
#               'special_services',
#               'small_payment',
#               'additional_assistance',
#               'direct_funding',
#               'free_services',
#               'more_funds',
#               'financial_help',
#               'financial_benefit',
#               'monetary_benefit',
#               'incentive_program',
#               'providing',
#               'more_service',
#               'voucher',
#               'incentive',
#               'handout',
#               'charitable_donations',
#               'donation',
#               'monthly_stipend',
#               'large_donation',
#               'more_funding',
#               'allowance',
#               'donations',
#               'enough_funds',
#               'grant',
#               'reimbursement',
#               'government_support',
#               'direct_benefit',
#               'reimbursing',
#               'mandate',
#               'government_money',
#               'tax_break',
#               'large_sum',
#               'government_funds',
#               'free_ride',
#               'handouts',
#               'social_services',
#               'bribe',
#               'incentives',
#               'vouchers',
#               'financial_assistance',
#               'services',
#               'necessary_funds',
#               'additional_support',
#               'food_assistance',
#               'aid',
#               'legal_assistance',
#               'token_amount',
#               'other_aid',
#               'free_help',
#               'hand_outs',
#               'government_service',
#               'compensation',
#               'monetary_support',
#               'government_program',
#               'further_support',
#               'return',
#               'receive',
#               'extra_services',
#               'state_funds',
#               'extra_funding',
#               'funds',
#               'monetary_compensation',
#               'extra_help',
#               'free_cash',
#               'taxpayer',
#               'additional_funds',
#               'assitance',
#               'offer',
#               'freebies',
#               'social_service',
#               'fund',
#               'public_funds'],
#              'contentment2': ['misery',
#               'thankfulness',
#               'mourning',
#               'yearning',
#               'overwhelming_sense',
#               'pride',
#               'happiness',
#               'delight',
#               'profound_sense',
#               'self-realization',
#               'gratitude',
#               'loving_kindness',
#               'peacefulness',
#               'godliness',
#               'indifference',
#               'bliss',
#               'dwell',
#               'deep_sense',
#               'tranquillity',
#               'pangs',
#               'great_sadness',
#               'desire',
#               'sadness',
#               'remembrance',
#               'reveling',
#               'great_joy',
#               'joyous',
#               'good_feelings',
#               'anguish',
#               'pure_joy',
#               'longing',
#               'majesty',
#               'calmness',
#               'wonderment',
#               'serenity',
#               'enlightenment',
#               'sweet_release',
#               'adoration',
#               'emptiness',
#               'revel',
#               'peace',
#               'comfort',
#               'overwhelming_feeling',
#               'jubilation',
#               'good_cheer',
#               'blissful',
#               'weariness',
#               'yearned',
#               'equanimity',
#               'glory',
#               'revelling',
#               'splendor',
#               'true_joy',
#               'contentedness',
#               'contentment',
#               'satisfaction',
#               'sufferings',
#               'stillness',
#               'fleeting',
#               'true_feeling',
#               'agony',
#               'feeling',
#               'realization',
#               'pure_happiness',
#               'tranquility',
#               'regret',
#               'pure_love',
#               'elation',
#               'aloneness',
#               'exhilaration',
#               'realisation',
#               'mirth',
#               'yearn',
#               'relishing',
#               'true_happiness',
#               'gratefulness',
#               'fleeting_moment',
#               'present_moment',
#               'respite',
#               'wholeness',
#               'warmth',
#               'joyful',
#               'catharsis',
#               'contemplation',
#               'genuine_happiness',
#               'inner_peace',
#               'pleasures',
#               'joy',
#               'pleasure',
#               'loneliness',
#               'holiness',
#               'sorrow',
#               'triumph'],
#              'writing2': ['notebook',
#               'scribbles',
#               'wacom_tablet',
#               'microsoft_word',
#               'note-taking',
#               'writing',
#               'paper',
#               'PDFs',
#               'note_book',
#               'note_pad',
#               'sticky_notes',
#               'write',
#               'OneNote',
#               'cursive',
#               'blackboard',
#               'note_cards',
#               'handwriting',
#               'scribble',
#               'flash_cards',
#               'Word_doc',
#               'powerpoint',
#               'personal_notes',
#               'longhand',
#               'hand_writing',
#               'blank_paper',
#               'lined_paper',
#               'lecture_notes',
#               'PowerPoint',
#               'MS_Word',
#               'onenote',
#               'note_card',
#               'sketching',
#               'doodle',
#               'written_notes',
#               'cheat_sheet',
#               'blank_sheet',
#               'notebook_paper',
#               'fountain_pen',
#               'handwritten_notes',
#               'typing',
#               'legibly',
#               'sketch_book',
#               'red_pen',
#               'whiteboard',
#               'powerpoint_slides',
#               'clipboard',
#               'real_paper',
#               'word_documents',
#               'powerpoints',
#               'annotating',
#               'notes',
#               'sketchpad',
#               'typeset',
#               'text_book',
#               'calligraphy',
#               'handwritten',
#               'Word_document',
#               'doodling',
#               'word_document',
#               'legal_pad',
#               'typewriter',
#               'annotate',
#               'Microsoft_Word',
#               'scratch_paper',
#               'Microsoft_word',
#               'own_handwriting',
#               'blank_pages',
#               'sketchbook',
#               'MS_word',
#               'notepads',
#               'chicken_scratch',
#               'jot',
#               'notepad',
#               'pencil',
#               'LaTeX',
#               'word_processor',
#               'scribbling',
#               'notebooks',
#               'handwrite',
#               'scrap_paper',
#               'class_notes',
#               'scribbled',
#               'jotting',
#               'school_papers',
#               'word_doc',
#               'Word',
#               'sticky_note',
#               'notecard',
#               'white_board'],
#              'rural2': ['north_east',
#               'great_lakes',
#               'northeast',
#               'gardens',
#               'pines',
#               'highland',
#               'country_side',
#               'rolling_hills',
#               'prairies',
#               'savannah',
#               'little_town',
#               'rainforest',
#               'north_shore',
#               'orchards',
#               'cornfields',
#               'rural',
#               'forrest',
#               'south_west',
#               'redwoods',
#               'central_valley',
#               'swamp',
#               'wetlands',
#               'oaks',
#               'cypress',
#               'south',
#               'northern',
#               'foothills',
#               'northern_part',
#               'grassland',
#               'Appalachian_mountains',
#               'ranches',
#               'north',
#               'north_part',
#               'mountains',
#               'eastern_side',
#               'forests',
#               'west_side',
#               'Mississippi_river',
#               'hill_country',
#               'south_east',
#               'idaho',
#               'riverside',
#               'farm_land',
#               'bayous',
#               'farmlands',
#               'lake',
#               'tundra',
#               'woodlands',
#               'mid-west',
#               'marsh',
#               'corn_fields',
#               'highlands',
#               'southeast',
#               'river',
#               'north_west',
#               'dunes',
#               'grasslands',
#               'far_north',
#               'everglades',
#               'bayou',
#               'badlands',
#               'valley',
#               'lakes',
#               'swamps',
#               'prairie',
#               'western_side',
#               'pine_trees',
#               'farm_fields',
#               'national_forest',
#               'marshes',
#               'downriver',
#               'desert',
#               'forest',
#               'plains',
#               'northwest',
#               'countryside',
#               'town',
#               'panhandle',
#               'inland',
#               'farmland',
#               'west',
#               'city',
#               'west_Texas',
#               'deserts',
#               'great_plains',
#               'farm_country',
#               'east_side',
#               'Appalachians'],
#              'positive_emotion2': ['sincere_desire',
#               'genuine_love',
#               'inspire',
#               'better',
#               'attitude',
#               'mindset',
#               'strong_sense',
#               'yearning',
#               'positive_way',
#               'honesty',
#               'pride',
#               'happiness',
#               'gratitude',
#               'happines',
#               'admiration',
#               'applaud',
#               'self-confidence',
#               'inspires',
#               'deep_sense',
#               'desire',
#               'humbleness',
#               'empathy',
#               'humility',
#               'fellow_human',
#               'strong_desire',
#               'appreciation',
#               'enthusiasm',
#               'ambition',
#               'good_feelings',
#               'thoughtfulness',
#               'ego',
#               'compassion',
#               'arrogance',
#               'selflessness',
#               'deep_desire',
#               'determination',
#               'hapiness',
#               'more_happiness',
#               'revel',
#               'little_pride',
#               'courage',
#               'at_least_a_little_bit',
#               'cynicism',
#               'comfort',
#               'positive_outlook',
#               'kindness',
#               'inner_strength',
#               'respect',
#               'confidence',
#               'motivates',
#               'dedication',
#               'gumption',
#               'perseverance',
#               'own_confidence',
#               'utmost',
#               'strive',
#               'own_sake',
#               'contentedness',
#               'contentment',
#               'satisfaction',
#               'happyness',
#               'self-satisfaction',
#               'true_feeling',
#               'personal_success',
#               'pity',
#               'just_love',
#               'admire',
#               'feeling',
#               'own_sense',
#               'hope',
#               'better_person',
#               'self_satisfaction',
#               'truly',
#               'real_love',
#               'striving',
#               'sincerity',
#               'brutal_honesty',
#               'greatness',
#               'love',
#               'self-love',
#               'motivation',
#               'true_happiness',
#               'own_motivation',
#               'optimism',
#               'gratefulness',
#               'self-respect',
#               'admirable',
#               'unconditional_love',
#               'eagerness',
#               'open-mindedness',
#               'inner_peace',
#               'little_happiness',
#               'own_self',
#               'positivity',
#               'joy',
#               'passion',
#               'embrace'],
#              'musical2': ['song',
#               'songs',
#               'tunes',
#               'piano_player',
#               'rhythm_guitarist',
#               'drum_beat',
#               'backup_vocals',
#               'backing_tracks',
#               'slide_guitar',
#               'drummers',
#               'synthesizer',
#               'riff',
#               'bass',
#               'trumpet_player',
#               'melodies',
#               'guitar_parts',
#               'bass_lines',
#               'full_orchestra',
#               'actual_songs',
#               'real_song',
#               'background_vocals',
#               'guitar_solo',
#               'guitar_player',
#               'few_songs',
#               'rhythm_guitar',
#               'saxophone',
#               'guitar_part',
#               'click_track',
#               'rock_song',
#               'musical',
#               'guitar_playing',
#               'first_song',
#               'harmonica',
#               'basslines',
#               'second_song',
#               'instrumentals',
#               'guitar_solos',
#               'piano_music',
#               'whole_band',
#               'particular_song',
#               'vocalist',
#               'pianist',
#               'original_song',
#               'acapella',
#               'acoustic',
#               'almost_every_song',
#               'bass_player',
#               'lead_guitarist',
#               'lead_guitar',
#               'acoustic_guitar',
#               'backing_vocals',
#               'second_track',
#               'backing_band',
#               'background_music',
#               'bass_line',
#               'sax',
#               'whole_song',
#               'actual_song',
#               'riffs',
#               'live_performance',
#               'most_songs',
#               'melody',
#               'actual_instruments',
#               'lyrics',
#               'guitar_work',
#               'guitar',
#               'full_band',
#               'electric_guitar',
#               'orchestra',
#               'duet',
#               'double_bass',
#               'harmonies',
#               'rock_band',
#               'acoustic_songs',
#               'drumming',
#               'drums',
#               'live_recording',
#               'live_performances',
#               'guitar_riffs',
#               'piano',
#               'chorus',
#               'keyboardist',
#               'entire_song',
#               'guitar_riff',
#               'singing',
#               'bassist',
#               'guitarist',
#               'bass_guitar',
#               'percussion',
#               'drummer',
#               'vocals',
#               'bass_part',
#               'backing_track',
#               'singer']})

# %%
#lexicon.create_category("help",["chore","responsible","help", "grateful", "maid"], model="reddit")

# %%
# Reading the text message data frame 
# implement only the participants with at least 2 messages (or more) 
# sort by conversation 
import pandas as pd
import re

# read the data frame 
dataFrame = pd.read_csv("sent14days.csv")
#print(dataFrame)

# obtain ID, texts, scores, and address 2 from dataframe
dataFrame = dataFrame[['id', 'body2', 'scores', 'address2']]
#print(dataFrame.head)

def firstVal(inList): 
    return inList[0]

def concat(inList): 
    return ". ".join(inList)

def scoreList(inList): 
    #print(list(inList))
    if len(inList) == 0: 
        return None
    else: 
        return list(inList)[0]

#group the data by participant and conversation
conversationsWFolds = dataFrame.copy()
conversationsWFolds["conversation"] = conversationsWFolds["id"] + "|TO|" +  conversationsWFolds["address2"]
#columns are id, fold, body2, depression, test and conversation
conversationsWFolds.columns
#print(conversationsWFolds["conversation"])
#group by conversation
groupedConvsWFolds = conversationsWFolds.groupby(by="conversation").agg({"body2": list, "scores": scoreList})
groupedConvsWFolds["Length Body"] = groupedConvsWFolds["body2"].apply(len)
groupedConvsWFolds["body2"] = groupedConvsWFolds["body2"].apply(concat)
#groupedConvsWFoldsReverse = conversationsWFolds.groupby(by="conversation").agg({"fold":firstVal, "body2": concatReverse, "depression": firstVal})

# create a new column to count # of text messages 
#newCol = groupedConvsFolds[['id', 'body2']].groupby(by = "id").agg(len)
#print(newCol)
# Group by ID
#dataFrame = dataFrame.groupby(by = "id").agg({"body2":sortList, "scores": scoreList})
#dataFrame['NumTexts'] = newCol
# only displays participants with 2 or more text messages
groupedConvsWFolds = groupedConvsWFolds[groupedConvsWFolds['Length Body'] >= 2]
#dataFrame.head()
#groupedConvsWFolds.head(40)

# %%
# Analyzing empath categories
#pDFt = dataFrame
pDFt = groupedConvsWFolds
for word in wordlist:
    #print(word)
    pctt = []
    for i in range(0, pDFt.shape[0]):
        content = re.sub(r'[^\w\s]', '', str(pDFt.body2[i]).lower())
        lexicon = Empath()
        #print(content)
        emp = lexicon.analyze(content, categories = [word], normalize = True)
        #print(emp)
        if emp != None:
            for key, value in emp.items(): 
                pctt.append(value)
        else:
            pctt.append(0)
    pDFt[word] = pctt
#pDFt.head()
pDFt.to_csv("ogEmpathConvo.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-06c7ed70a354> in <module>
#       1 # Analyzing empath categories
#       2 #pDFt = dataFrame
# ----> 3 pDFt = groupedConvsWFolds
#       4 for word in wordlist:
#       5     #print(word)
#
# NameError: name 'groupedConvsWFolds' is not defined

# %%
print(pDFt)

# %%
# Analyze my created categories

pDFt = groupedConvsWFolds
# renaming body2 to text (so that the category body2 doesn't get confused)
pDFt.rename(columns = {'body2':'text'}, inplace = True)
print(pDFt.rename)
#print(pDFt.head())

# loops through my created categories 
for word in myCategories:
    print(word)
    if "2" in word: 
        pctt = []
        for i in range(0, pDFt.shape[0]):
            #print("good")
            content = re.sub(r'[^\w\s]', '', str(pDFt.text[i]).lower())
            lexicon = Empath()
            #print(content)
            emp = lexicon.analyze(content, categories = [word], normalize = True)
            #print(emp)
            if emp != None:
                for key, value in emp.items():
                    pctt.append(value)
            else:
                pctt.append(0)
        pDFt[word] = pctt
#pDFt.head()
pDFt.to_csv("myEmpathConvo.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b292745679e6> in <module>
#       1 # Analyze my created categories
#       2
# ----> 3 pDFt = groupedConvsWFolds
#       4 # renaming body2 to text (so that the category body2 doesn't get confused)
#       5 pDFt.rename(columns = {'body2':'text'}, inplace = True)
#
# NameError: name 'groupedConvsWFolds' is not defined
